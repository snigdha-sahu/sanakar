# %% [markdown]
# # ROCK PAPER SCISSOR GAME

# %%
import random

#Rock beats scissors, scissors beat paper, and paper beats rock.

R = 'Rock'
P = 'Paper'
S = 'Scissors'

list = [ R , P , S]

while True:
    usercount = 0
    comcount = 0
    
    uc=int(input('''
Game Start
1. yes
2. Exit
              '''))
    
    if uc==1:
        for a in range(1,6):
            userchoice = int(input('''
1. Rock   
2. Paper
3. scissors       
                              '''))
            if userchoice ==1:
                userchoice = R
            elif userchoice ==2:
                userchoice= P
            elif userchoice== 3:
                userchoice = S
                
            compchoice = random.choice(list)
            
            if userchoice == compchoice:
                print('yourchoice is',userchoice)
                print('Computer choice is',compchoice)
                print('Game Draw')
                usercount =usercount+1
                comcount = comcount + 1
            
                
            elif (userchoice == R and compchoice == S) or (userchoice == S and compchoice == P) or (userchoice == P and compchoice == R):
                print('yourchoice is',userchoice)
                print('Computer choice is',compchoice)
                print('You Win')
                usercount = usercount + 1
                
            else:
                print('Yourchoice is',userchoice)
                print('Computer choice is',compchoice)
                print('Computer Win')
                comcount = comcount +1
        
        if usercount == comcount:
            print('Game Draw')
            print('Your score is', usercount)
            print('Computer Score is', comcount)
            
        elif usercount > comcount:
            print('You Win')
            print('Your score is', usercount)
            print('Computer Score is', comcount)
            
        else:
            print('Computer Win')
            print('Your score is', usercount)
            print('Computer Score is', comcount)
                
                
    else:
        break
# Out:
# Game Start
# 1. yes
# 2. Exit
#               1
#
# 1. Rock
# 2. Paper
# 3. scissors
#                               2
# Yourchoice is Paper
# Computer choice is Scissors
# Computer Win
#
# 1. Rock
# 2. Paper
# 3. scissors
#                               3
# yourchoice is Scissors
# Computer choice is Scissors
# Game Draw
#
# 1. Rock
# 2. Paper
# 3. scissors
#                               3
# Yourchoice is Scissors
# Computer choice is Rock
# Computer Win
#
# 1. Rock
# 2. Paper
# 3. scissors
#                               4
# Yourchoice is 4
# Computer choice is Rock
# Computer Win
#
# 1. Rock
# 2. Paper
# 3. scissors
#                               8
# Yourchoice is 8
# Computer choice is Paper
# Computer Win
# Computer Win
# Your score is 1
# Computer Score is 5
#
# Game Start
# 1. yes
# 2. Exit
#               2
